# %% [markdown]
# **Tweet Scraping for Sentiment Analysis Without Twitter API**
#
# This web-scraping script uses snscrape to collect tweets of a user inputted query.

# %% [markdown]
# **Import Libraries**

# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd

# %% [markdown]
# **Functions to Scrape and Save Tweets to CSV**

# %%
def get_tweets(query, tweets, limit):
    for tweet in sntwitter.TwitterSearchScraper(query).get_items():
    
        # print(vars(tweet))
        # break
        if len(tweets) == limit:
            break
        else:
            tweets.append([tweet.date, tweet.place, tweet.username, tweet.content])
    return tweets

# %%
def save_to_csv(tweets):
    df = pd.DataFrame(tweets, columns=['Date', 'Location', 'User', 'Tweet'])
    print(df)

    # to save to csv
    df.to_csv('tweets/tweets.csv')
    return tweets

# %%
query = "(warriors OR celtics) -RT -retweet -like (#warriors OR #celtics OR #nba OR #nbafinals) lang:en until:2022-06-06 since:2022-06-01 -filter:links"
tweets = []
limit = 1000
get_tweets(query, tweets, limit)
save_to_csv(tweets)
# Out:
# /tmp/ipykernel_1577/1406240920.py:9: FutureWarning: username is deprecated, use user.username instead
#   tweets.append([tweet.date, tweet.place, tweet.username, tweet.content])
#                          Date Location             User  \
# 0   2022-06-05 22:16:47+00:00     None    RoseSportsPod
# 1   2022-06-05 22:16:19+00:00     None      davemcswain
# 2   2022-06-05 22:15:25+00:00     None      CCSports305
# 3   2022-06-05 22:14:20+00:00     None      nickvaughn1
# 4   2022-06-05 22:11:23+00:00     None  marcelinhofella
# ..                        ...      ...              ...
# 995 2022-06-03 17:32:54+00:00     None     FOE5frmdaRAQ
# 996 2022-06-03 17:29:48+00:00     None      PCwarrior69
# 997 2022-06-03 17:28:41+00:00     None    thejoelwright
# 998 2022-06-03 17:27:36+00:00     None     TheRocketGuy
# 999 2022-06-03 17:26:18+00:00     None     PeteyWeeStro
#
#                                                  Tweet
# 0    Warriors Andre Iguodala is out for Game 2 vs. ...
# ...
